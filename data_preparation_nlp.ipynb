# %% [markdown]
# # Exercises
#
# The end result of this exercise should be a file named prepare.py that defines the requested functions.
#
# In this exercise we will be defining some functions to prepare textual data. These functions should apply equally well to both the codeup blog articles and the news articles that were previously acquired.

# %%
import pandas as pd

import unicodedata
import re

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nickolaspedrimiranda/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/nickolaspedrimiranda/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## 1. Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# * Lowercase everything
# * Normalize unicode characters
# * Replace anything that is not a letter, number, whitespace or a single quote.

# %%
def basic_clean(filthy_data):
    filthy_data = filthy_data.lower()
    filthy_data = unicodedata.normalize('NFKD', filthy_data).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    clean_data = re.sub(r"[^a-z0-9'\s]", "", filthy_data)
    return clean_data

# %% [markdown]
# ## 2. Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(data):
    tokenizer = ToktokTokenizer()
    data = tokenizer.tokenize(data, return_str=True)
    return data

# %% [markdown]
# ## 3. Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(data):
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in data.split()]
    stemmed_data = ' '.join(stems)
    return stemmed_data

# %% [markdown]
# ## 4. Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(data):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in data.split()]
    lemmatized_data = ' '.join(lemmas)
    return lemmatized_data

# %% [markdown]
# ## 5. Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
#
# This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
# This function takes in a string, optional extra_words and exclued_words parameters with default empty lists and returns a string
def remove_stopwords(string, extra_words = [], exclude_words = []):
    stopword_list = stopwords.words('english')
    # use set casting to remove any excluded stopwords
    stopword_set = set(stopword_list) - set(exclude_words)
    # add in extra words to stopwords set using a union
    stopword_set = stopword_set.union(set(extra_words))
    # split the document by spaces
    words = string.split()
    # every word in our document that is not a stopword
    filtered_words = [word for word in words if word not in stopword_set]
    # join it back together with spaces
    string_without_stopwords = ' '.join(filtered_words)
    return string_without_stopwords

# %%
#def remove_stopwords(data, exclude=[], include=[]):
#    stopwords_list = stopwords.words('english')
#    words = [word for word in data.split() if word not in stopwords_list]
#    new_data = ' '.join(words)
#    return new_data

# %% [markdown]
# ## 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
news = pd.read_csv('news.csv')
news = news.rename(columns={'content':'original'})
news = news.drop(columns='category')

# %%
def cleanse(df, col='', stem=False, lem=True):
    df['clean'] = df[col].apply(basic_clean)
    return df

# %%
cleanse(news, 'original')
# Out:
#                                                 title  \
# 0   Govt probing accounts of Adani Group-run Mumba...
# 1   IndiGo Co-founder Gangwal to buy SpiceJet stak...
# 2   Who is KP Ramasamy, a farmer's son who entered...
# 3   Zomato, McDonald's fined ₹1 lakh for deliverin...
# 4   India scraps plan to impose restrictions on la...
# 5   Trader wins ₹8,225 compensation from Zerodha o...
# 6   I'm surprised by how much difference being Ind...
# 7   Debt isn't bad, it should be there for develop...
# 8   Stopped buying from ultra-luxury brands like H...
# 9   Very concerned, don't know all facts: MoS IT o...
# 10  Andhra govt trying to give steroids to Naidu i...
# 11  Go to Asian Games & win medals: UP Dy CM on Ak...
# 12  Narendra Modi Adani's PM, not India's: Sanjay ...
# 13  UP Deputy CM renames himself as 'Servant Braje...
# 14  India facing cross-border terrorism for decade...
# 15  Congress shares 'inseparable' meme, captions i...
# 16  World running due to Sanatana, it's synonymous...
# 17  P20 Summit is 'Mahakumbh' of parliamentary pra...
# 18  PM's PR hides poor behind curtains: Saket on G...
# 19  AAP MP moves Delhi HC challenging arrest in ex...
# 20  Who won Player of the Match awards in previous...
# 21  What was India's margin of victory against Pak...
# 22  If Babar Azam starts playing, nobody can stop ...
# 23  I think Virat will win battle against Shaheen ...
# 24  What is the weather forecast for Ahmedabad whe...
# 25  Shubman Gill is 99% available for match agains...
# 26  Cook retires after scoring 34,045 runs and sma...
# 27  Who has smashed the highest score in India-Pak...
# 28  All streaks are meant to be broken: Babar on P...
# 29  X user says Khamenei got grey tick, Musk says ...
# 30  India scraps plan to impose restrictions on la...
# 31  Pics show 1st mobile tower at Siachen Glacier,...
# 32  Very concerned, don't know all facts: MoS IT o...
# 33  Microsoft's $69 billion Activision deal, bigge...
# 34  Grandfather fought in WWII for 6 yrs, dropped ...
# 35  No place for terrorist groups: X to EU on disi...
# 36  Microsoft shuts Windows 7, 8 users' free upgra...
# 37  FTX Founder tried to get funds from Saudi Crow...
# 38            HCLTech to hire 10,000 freshers in FY24
#
#                                              original  \
# 0   The Ministry of Corporate Affairs has opened a...
# 1   IndiGo Co-founder Rakesh Gangwal is at advance...
# 2   KP Ramasamy has made his debut on Forbes India...
# 3   Food delivery platform Zomato and fast food ch...
# 4   The Indian government has reversed its decisio...
# 5   Trader Vijay Gupta won ₹8,225 compensation fro...
# 6   World Bank President Ajay Banga said he's surp...
# 7   World Bank President Ajay Banga said debt isn'...
# 8   Zerodha Co-founder Nikhil Kamath said he no lo...
# 9   Minister of State for IT Rajeev Chandrasekhar ...
# 10  The Andhra Pradesh government is trying to adm...
# 11  UP Deputy CM Brajesh Pathak has reacted to a v...
# 12  AAP shared a video of MP Sanjay Singh while he...
# 13  Uttar Pradesh Deputy Chief Minister Brajesh Pa...
# 14  While addressing the 9th P20 Summit, PM Narend...
# 15  Congress shared an "inseparable" meme on PM Na...
# 16  Amid controversy over DMK leader Udhayanidhi S...
# 17  PM Narendra Modi, after inaugurating the 9th G...
# 18  TMC MP Saket Gokhale criticised PM Narendra Mo...
# 19  AAP MP Sanjay Singh has approached Delhi High ...
# 20  Sachin Tendulkar was named Player of the Match...
# 21  India have won all seven matches against Pakis...
# 22  Ahead of India-Pakistan match, ex-India cricke...
# 23  Former India cricketer Harbhajan Singh said th...
# 24  India-Pakistan ODI World Cup 2023 match will b...
# 25  Team India captain Rohit Sharma has said that ...
# 26  Former England captain Alastair Cook has annou...
# 27  Rohit Sharma holds the record for smashing the...
# 28  Talking about Pakistan's 0-7 record against In...
# 29  An X user shared a screenshot of Iran's Suprem...
# 30  The Indian government has reversed its decisio...
# 31  The first-ever mobile tower has been installed...
# 32  Minister of State for IT Rajeev Chandrasekhar ...
# 33  UK's Competition and Markets Authority has app...
# 34  Billionaire Elon Musk said his grandfather fou...
# 35  X CEO Linda Yaccarino replied to EU industry c...
# 36  Microsoft has now blocked Windows 7 and Window...
# 37  FTX Founder Sam Bankman-Fried said he might tr...
# 38  HCLTech said it will target hiring 10,000 fres...
#
#                                                 clean
# 0   the ministry of corporate affairs has opened a...
# 1   indigo cofounder rakesh gangwal is at advanced...
# 2   kp ramasamy has made his debut on forbes india...
# 3   food delivery platform zomato and fast food ch...
# 4   the indian government has reversed its decisio...
# 5   trader vijay gupta won 8225 compensation from ...
# 6   world bank president ajay banga said he's surp...
# 7   world bank president ajay banga said debt isn'...
# 8   zerodha cofounder nikhil kamath said he no lon...
# 9   minister of state for it rajeev chandrasekhar ...
# 10  the andhra pradesh government is trying to adm...
# 11  up deputy cm brajesh pathak has reacted to a v...
# 12  aap shared a video of mp sanjay singh while he...
# 13  uttar pradesh deputy chief minister brajesh pa...
# 14  while addressing the 9th p20 summit pm narendr...
# 15  congress shared an inseparable meme on pm nare...
# 16  amid controversy over dmk leader udhayanidhi s...
# 17  pm narendra modi after inaugurating the 9th g2...
# 18  tmc mp saket gokhale criticised pm narendra mo...
# 19  aap mp sanjay singh has approached delhi high ...
# 20  sachin tendulkar was named player of the match...
# 21  india have won all seven matches against pakis...
# 22  ahead of indiapakistan match exindia cricketer...
# 23  former india cricketer harbhajan singh said th...
# 24  indiapakistan odi world cup 2023 match will be...
# 25  team india captain rohit sharma has said that ...
# 26  former england captain alastair cook has annou...
# 27  rohit sharma holds the record for smashing the...
# 28  talking about pakistan's 07 record against ind...
# 29  an x user shared a screenshot of iran's suprem...
# 30  the indian government has reversed its decisio...
# 31  the firstever mobile tower has been installed ...
# 32  minister of state for it rajeev chandrasekhar ...
# 33  uk's competition and markets authority has app...
# 34  billionaire elon musk said his grandfather fou...
# 35  x ceo linda yaccarino replied to eu industry c...
# 36  microsoft has now blocked windows 7 and window...
# 37  ftx founder sam bankmanfried said he might try...
# 38  hcltech said it will target hiring 10000 fresh...

# %%
news.head()
# Out:
#                                                title  \
# 0  Govt probing accounts of Adani Group-run Mumba...
# 1  IndiGo Co-founder Gangwal to buy SpiceJet stak...
# 2  Who is KP Ramasamy, a farmer's son who entered...
# 3  Zomato, McDonald's fined ₹1 lakh for deliverin...
# 4  India scraps plan to impose restrictions on la...
#
#                                             original  \
# 0  The Ministry of Corporate Affairs has opened a...
# 1  IndiGo Co-founder Rakesh Gangwal is at advance...
# 2  KP Ramasamy has made his debut on Forbes India...
# 3  Food delivery platform Zomato and fast food ch...
# 4  The Indian government has reversed its decisio...
#
#                                                clean
# 0  the ministry of corporate affairs has opened a...
# 1  indigo cofounder rakesh gangwal is at advanced...
# 2  kp ramasamy has made his debut on forbes india...
# 3  food delivery platform zomato and fast food ch...
# 4  the indian government has reversed its decisio...

# %% [markdown]
# ## 7. Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
import prepare_nlp
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nickolaspedrimiranda/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/nickolaspedrimiranda/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
codeup = pd.read_csv('codeup_blogs.csv')
codeup = codeup.rename(columns={'content':'original'})
codeup = codeup.dropna()
codeup.head(3)
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
#
#                                             original
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...

# %%
prepare_nlp.cleanse(codeup, 'original')
# Out:
#                                                  title  \
# 0    Spotlight on APIDA Voices: Celebrating Heritag...
# 1    Women in tech: Panelist Spotlight – Magdalena ...
# 2    Women in tech: Panelist Spotlight – Rachel Rob...
# 3     Women in Tech: Panelist Spotlight – Sarah Mellor
# 4    Women in Tech: Panelist Spotlight – Madeleine ...
# ..                                                 ...
# 265  Why Isn’t the San Antonio Tech Scene Growing F...
# 266    Why People Can’t Learn Programming on Their Own
# 267                           What is Our Noble Cause?
# 268         Scholarships for Women: Why We’re Doing It
# 269                    Student Profile: Leslie Tolbert
#
#                                               original  \
# 0    May is traditionally known as Asian American a...
# 1    Codeup is hosting a Women in Tech Panel in hon...
# 2    Codeup is hosting a Women in Tech Panel in hon...
# 3    Codeup is hosting a Women in Tech Panel in hon...
# 4    Codeup is hosting a Women in Tech Panel in hon...
# ..                                                 ...
# 265  The simple answer is computer programming tale...
# 266  While developing Codeup, we interviewed dozens...
# 267  In his TEDx San Antonio presentation this fall...
# 268  A hot topic that is trending is the special tr...
# 269  Leslie Tolbert, Texas State graduate and commu...
#
#                                                  clean  \
# 0    may traditionally known asian american pacific...
# 1    codeup hosting women tech panel honor womens h...
# 2    codeup hosting women tech panel honor womens h...
# 3    codeup hosting women tech panel honor womens h...
# 4    codeup hosting women tech panel honor womens h...
# ..                                                 ...
# 265  simple answer computer programming talent peop...
# 266  developing codeup interviewed dozens people at...
# 267  tedx san antonio presentation fall nick longo ...
# 268  hot topic trending special treatment ladies te...
# 269  leslie tolbert texas state graduate communicat...
#
#                                                stemmed  \
# 0    may tradit known asian american pacif island a...
# 1    codeup host women tech panel honor women histo...
# 2    codeup host women tech panel honor women histo...
# 3    codeup host women tech panel honor women histo...
# 4    codeup host women tech panel honor women histo...
# ..                                                 ...
# 265  simpl answer comput program talent peopl take ...
# 266  develop codeup interview dozen peopl attempt l...
# 267  tedx san antonio present fall nick longo cofou...
# 268  hot topic trend special treatment ladi tech in...
# 269  lesli tolbert texa state graduat commun design...
#
#                                             lemmatized
# 0    may traditionally known asian american pacific...
# 1    codeup hosting woman tech panel honor woman hi...
# 2    codeup hosting woman tech panel honor woman hi...
# 3    codeup hosting woman tech panel honor woman hi...
# 4    codeup hosting woman tech panel honor woman hi...
# ..                                                 ...
# 265  simple answer computer programming talent peop...
# 266  developing codeup interviewed dozen people att...
# 267  tedx san antonio presentation fall nick longo ...
# 268  hot topic trending special treatment lady tech...
# 269  leslie tolbert texas state graduate communicat...
#
# [268 rows x 5 columns]

# %%
codeup.head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
#
#                                                clean
# 0  may is traditionally known as asian american a...
# 1  codeup is hosting a women in tech panel in hon...
# 2  codeup is hosting a women in tech panel in hon...
# 3  codeup is hosting a women in tech panel in hon...
# 4  codeup is hosting a women in tech panel in hon...

# %% [markdown]
# ## 8. For each dataframe, produce the following columns:
#
# * 'title' to hold the title
# * 'original' to hold the original article/post content
# * 'clean' to hold the normalized and tokenized original with the stopwords removed.
# * 'stemmed' to hold the stemmed version of the cleaned data.
# * 'lemmatized' to hold the lemmatized version of the cleaned data.

# %%
def clean_column(series):
    new_series = []
    #i = 0
    for col in series:
        #print(type(blog), i)
        #i+=1
        data = basic_clean(col)
        data = tokenize(data)
        data = remove_stopwords(data)
        new_series.append(data)
    return new_series

# %%
codeup['clean'] = clean_column(codeup.original)
codeup.head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
#
#                                                clean
# 0  may traditionally known asian american pacific...
# 1  codeup hosting women tech panel honor womens h...
# 2  codeup hosting women tech panel honor womens h...
# 3  codeup hosting women tech panel honor womens h...
# 4  codeup hosting women tech panel honor womens h...

# %%
news['clean'] = clean_column(news.original)
news.head()
# Out:
#                                                title  \
# 0  Govt probing accounts of Adani Group-run Mumba...
# 1  IndiGo Co-founder Gangwal to buy SpiceJet stak...
# 2  Who is KP Ramasamy, a farmer's son who entered...
# 3  Zomato, McDonald's fined ₹1 lakh for deliverin...
# 4  India scraps plan to impose restrictions on la...
#
#                                             original  \
# 0  The Ministry of Corporate Affairs has opened a...
# 1  IndiGo Co-founder Rakesh Gangwal is at advance...
# 2  KP Ramasamy has made his debut on Forbes India...
# 3  Food delivery platform Zomato and fast food ch...
# 4  The Indian government has reversed its decisio...
#
#                                                clean
# 0  ministry corporate affairs opened investigatio...
# 1  indigo cofounder rakesh gangwal advanced stage...
# 2  kp ramasamy made debut forbes india ' 100 rich...
# 3  food delivery platform zomato fast food chain ...
# 4  indian government reversed decision imposing r...

# %%
def stem_column(series):
    stemmed_data = []
    for col in series:
        data = stem(col)
        stemmed_data.append(data)
    return stemmed_data

# %%
codeup['stemmed'] = stem_column(codeup.clean)
codeup.head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
#
#                                                clean  \
# 0  may traditionally known asian american pacific...
# 1  codeup hosting women tech panel honor womens h...
# 2  codeup hosting women tech panel honor womens h...
# 3  codeup hosting women tech panel honor womens h...
# 4  codeup hosting women tech panel honor womens h...
#
#                                              stemmed
# 0  may tradit known asian american pacif island a...
# 1  codeup host women tech panel honor women histo...
# 2  codeup host women tech panel honor women histo...
# 3  codeup host women tech panel honor women histo...
# 4  codeup host women tech panel honor women histo...

# %%
news['stemmed'] = stem_column(news.clean)
news.head()
# Out:
#                                                title  \
# 0  Govt probing accounts of Adani Group-run Mumba...
# 1  IndiGo Co-founder Gangwal to buy SpiceJet stak...
# 2  Who is KP Ramasamy, a farmer's son who entered...
# 3  Zomato, McDonald's fined ₹1 lakh for deliverin...
# 4  India scraps plan to impose restrictions on la...
#
#                                             original  \
# 0  The Ministry of Corporate Affairs has opened a...
# 1  IndiGo Co-founder Rakesh Gangwal is at advance...
# 2  KP Ramasamy has made his debut on Forbes India...
# 3  Food delivery platform Zomato and fast food ch...
# 4  The Indian government has reversed its decisio...
#
#                                                clean  \
# 0  ministry corporate affairs opened investigatio...
# 1  indigo cofounder rakesh gangwal advanced stage...
# 2  kp ramasamy made debut forbes india ' 100 rich...
# 3  food delivery platform zomato fast food chain ...
# 4  indian government reversed decision imposing r...
#
#                                              stemmed
# 0  ministri corpor affair open investig account a...
# 1  indigo cofound rakesh gangwal advanc stage tal...
# 2  kp ramasami made debut forb india ' 100 riches...
# 3  food deliveri platform zomato fast food chain ...
# 4  indian govern revers decis impos restrict lapt...

# %%
def lem_column(series):
    lem_data = []

    for col in series:
        data = lemmatize(col)
        lem_data.append(data)
    return lem_data

# %%
codeup['lemmatized'] = lem_column(codeup.clean)
codeup.head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Codeup is hosting a Women in Tech Panel in hon...
# 2  Codeup is hosting a Women in Tech Panel in hon...
# 3  Codeup is hosting a Women in Tech Panel in hon...
# 4  Codeup is hosting a Women in Tech Panel in hon...
#
#                                                clean  \
# 0  may traditionally known asian american pacific...
# 1  codeup hosting women tech panel honor womens h...
# 2  codeup hosting women tech panel honor womens h...
# 3  codeup hosting women tech panel honor womens h...
# 4  codeup hosting women tech panel honor womens h...
#
#                                              stemmed  \
# 0  may tradit known asian american pacif island a...
# 1  codeup host women tech panel honor women histo...
# 2  codeup host women tech panel honor women histo...
# 3  codeup host women tech panel honor women histo...
# 4  codeup host women tech panel honor women histo...
#
#                                           lemmatized
# 0  may traditionally known asian american pacific...
# 1  codeup hosting woman tech panel honor woman hi...
# 2  codeup hosting woman tech panel honor woman hi...
# 3  codeup hosting woman tech panel honor woman hi...
# 4  codeup hosting woman tech panel honor woman hi...

# %%
news['lemmatized'] = lem_column(news.clean)
news.head()
# Out:
#                                                title  \
# 0  Govt probing accounts of Adani Group-run Mumba...
# 1  IndiGo Co-founder Gangwal to buy SpiceJet stak...
# 2  Who is KP Ramasamy, a farmer's son who entered...
# 3  Zomato, McDonald's fined ₹1 lakh for deliverin...
# 4  India scraps plan to impose restrictions on la...
#
#                                             original  \
# 0  The Ministry of Corporate Affairs has opened a...
# 1  IndiGo Co-founder Rakesh Gangwal is at advance...
# 2  KP Ramasamy has made his debut on Forbes India...
# 3  Food delivery platform Zomato and fast food ch...
# 4  The Indian government has reversed its decisio...
#
#                                                clean  \
# 0  ministry corporate affairs opened investigatio...
# 1  indigo cofounder rakesh gangwal advanced stage...
# 2  kp ramasamy made debut forbes india ' 100 rich...
# 3  food delivery platform zomato fast food chain ...
# 4  indian government reversed decision imposing r...
#
#                                              stemmed  \
# 0  ministri corpor affair open investig account a...
# 1  indigo cofound rakesh gangwal advanc stage tal...
# 2  kp ramasami made debut forb india ' 100 riches...
# 3  food deliveri platform zomato fast food chain ...
# 4  indian govern revers decis impos restrict lapt...
#
#                                           lemmatized
# 0  ministry corporate affair opened investigation...
# 1  indigo cofounder rakesh gangwal advanced stage...
# 2  kp ramasamy made debut forbes india ' 100 rich...
# 3  food delivery platform zomato fast food chain ...
# 4  indian government reversed decision imposing r...

# %%
news.clean.iloc[0]
# Out:
# 'ministry corporate affairs opened investigation accounts adani grouprun mumbai navi mumbai airports significant part information sought government pertains period fiscal 2018 2022 prior acquisition adani enterprises said company stated units respond communications applicable legal provisions'

# %%
news.lemmatized.iloc[0]
# Out:
# 'ministry corporate affair opened investigation account adani grouprun mumbai navi mumbai airport significant part information sought government pertains period fiscal 2018 2022 prior acquisition adani enterprise said company stated unit respond communication applicable legal provision'

# %% [markdown]
# ## 9. Ask yourself:
#
# * If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
# * If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
# * If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?

# %%
# FOR THE 200TB OF TEXT I WOULD STEM, BECAUSE IT WOULD BE FAR TOO COMPUTATIONALLY DEMANDING TO LEMMATIZE IT ESPECIALLY ON PAID COMPUTATIONAL RESOURCES.
